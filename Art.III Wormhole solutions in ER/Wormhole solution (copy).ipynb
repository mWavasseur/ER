# %% [markdown]
# # WORMHOLE SOLUTION IN EMD AND ER THEORIES

# %% [markdown]
# \begin{eqnarray}
# \nabla_\mu \left( e^{-2 \alpha_0 \phi} F^{\mu \nu} \right) &=& 0, \\
# \epsilon_0 \nabla^2 \phi + \frac{\alpha_0}{2} \left( e^{-2 \alpha_0 \phi} F^2 \right) &=& 0, \\
# R_{\mu \nu} &=& 2 \epsilon_0 \nabla_\mu \phi \nabla_\nu \phi
# + 2 e^{-2 \alpha_0 \phi} \left( F_{\mu \sigma} F_\nu{}^{\sigma} - \frac{1}{4} g_{\mu \nu} F^2 \right), \\
# \alpha_0^2 (4k_0 + 1) - 4\epsilon_0 &=& 0.
# \end{eqnarray}
#
#
# \begin{equation}
# ds^2 = -f \left( dt - \frac{\omega}{L} d[L\varphi] \right)^2 + L^2 f^{-1} \left( \frac{(x^2 + 1)(1 - y^2)}{L^2} d[L\varphi]^2 \right) + (x^2 + y^2) e^{2k} \left\{ \frac{dx^2}{x^2 + 1} + \frac{dy^2}{1 - y^2} \right\},
# \end{equation}
#
# \begin{equation}
# f = f_0 = 1, \quad \omega = -L \frac{\lambda_0}{f_0} \left( \frac{y(x^2 + 1)}{x^2 + y^2} \right),
# \end{equation}
#
# \begin{equation}
# A_{\varphi} = -\frac{\sqrt{f_0}}{2\kappa_0} \frac{\omega}{L} e^{-\lambda_5}, \quad A_t = \frac{\sqrt{f_0}}{2\kappa_0} e^{-\lambda_5},
# \end{equation}
#
# \begin{equation}
# k = -k_0 \lambda_0^2 \frac{(1 - y^2)}{4(x^2 + y^2)^4}\left(-8x^2 y^2 (x^2 + 1)+ [x^2 + y^2]^2 \left[ (1 - y^2) +2(x^2 + y^2) \right]\right).
# \end{equation}
#
# \begin{equation}
# \lambda_5 = \lambda_0 \frac{x}{x^2 + y^2} + m_0,
# \end{equation}

# %%
version()
# Out:
# 'SageMath version 10.1, Release Date: 2023-08-20'

# %% [markdown]
# 'SageMath version used is 10.1, Release Date: 2023-08-20'

# %%
# %display latex

# %%
from sage.manifolds.operators import dalembertian
from sage.manifolds.operators import laplacian
from sage.manifolds.operators import grad
from sage.symbolic.operators import FDerivativeOperator

# %%
def subs_func(arg):
    subs_funcs = [(V, B), (X, C), (Y, D), (Z, omeg), (A_t, At_expr), (A_phi, Ap_expr), \
                  (omega, omeg), (nu, Nu_expr), (Xi, Xi_expr), \
                 (Psi, Psi_sc), (lambda5, lambda5_func)]
    
    if hasattr(arg, 'expr'):
        arg = arg.expr()
        
    if hasattr(arg, 'apply_map')*hasattr(arg, 'display'):
        for old_func, new_func in subs_funcs:
            arg.apply_map(lambda f: f.substitute_function(old_func, new_func))
    else:
        for old_func, new_func in subs_funcs:
            arg = arg.substitute_function(old_func, new_func)        
    return arg

# %%
M = Manifold(4, 'M', structure='Lorentzian')
print(M)
# Out:
# 4-dimensional Lorentzian manifold M

# %%
XY.<t,x,y,ph> = M.chart(r"t x y ph:(0,2*pi):\varphi")
XY
# Out:
# Chart (M, (t, x, y, ph))

# %% [markdown]
# # I. Definition of the metric

# %%
V = function('V')
X = function('X')
Y = function('Y')
Z = function('Z')

Psi = function('Psi')
A_t = function('A_t')
A_phi = function('A_phi')

# %%
g = M.lorentzian_metric('g')

g[0,0] = -1
g[0,3] = g[3,0] = Z(x,y) 
g[1,1] = V(x,y)
g[2,2] = X(x,y)
g[3,3] = Y(x,y)

show(LatexExpr(r'g_{\mu\nu} = '), g[:])
# Out:
# g_{\mu\nu} =  [     -1       0       0 Z(x, y)]
# [      0 V(x, y)       0       0]
# [      0       0 X(x, y)       0]
# [Z(x, y)       0       0 Y(x, y)]

# %%
nab = g.connection()

# %% [markdown]
# # II. Definition of the potential vector

# %%
pot_vec = M.tensor_field(0,1,name='A')

pot_vec[0] = A_t(x,y)
pot_vec[1]=0
pot_vec[2]=0
pot_vec[3]= A_phi(x,y)

show(pot_vec.display())
# Out:
# A = A_t(x, y) dt + A_phi(x, y) dph

# %%
DF = nab(pot_vec) ; DF
# Out:
# Tensor field nabla_g(A) of type (0,2) on the 4-dimensional Lorentzian manifold M

# %% [markdown]
# # III. Defintion of the EM tensor

# %%
F = diff(pot_vec)
F.set_name('F')
Fuu = F.up(g)
F.display()
# Out:
# F = -d(A_t)/dx dt∧dx - d(A_t)/dy dt∧dy + d(A_phi)/dx dx∧dph + d(A_phi)/dy dy∧dph

# %% [markdown]
# # IV. Model

# %%
L, alpha0, lambda0, k0, f0 = var('L alpha0 lambda_0 k_0 f0')
omega = function('omega')
ka = function('k')
lambda5 = function('lambda_5')
Xi = function('Xi')
Nu = function('nu')

# %%
show(LatexExpr(r'k_0 =\frac{47}{4}'))
show(LatexExpr(r'f_0 =1'))
show(LatexExpr(r'\lambda_0 =1/10'))
show(LatexExpr(r'm_0 =0'))
show(LatexExpr(r'L =10')) # This parameter is associated to the WH throat size
# Out:
# k_0 =\frac{47}{4}
# f_0 =1
# \lambda_0 =1/10
# m_0 =0
# L =10

# %% [markdown]
# ## IV. 2 Functions

# %%
lambda5_func(x,y) = lambda0*x/(x**2+y**2)
omeg(x,y) = -L * lambda0 / (y * (x^2 + 1)) / (x^2 + y^2)
kappa(x,y) = -k0 * lambda0^2 * (1 - y^2)^2 / (4 * (x^2 + y^2)^4) * ( -8 * x^2 * y^2 * (x^2 + 1) + (x^2 + y^2)^2 * ((1 - y^2) + 2 * (x^2 + y^2)))
Xi_expr(x,y) = exp(2*kappa(x,y))
Nu_expr(x,y) = exp(-lambda5(x,y))
#Phi_sc = M.scalar_field({XY:-lambda5(x,y)/alpha0}, name=r'\varphi')
#Psi_sc = M.scalar_field({XY: exp(2 * alpha0 * Phi_sc.expr())}, name='Psi')
Phi_sc(x,y) = -lambda5(x,y)/alpha0
Psi_sc(x,y) = exp(2 * alpha0 * Phi_sc(x,y))

# %%
show(LatexExpr(r'\lambda_5(x,y) = '), lambda5_func(x,y))
show(LatexExpr(r'\nu(x,y) = '), Nu_expr(x,y))
show(LatexExpr(r'\omega(x,y) = '), omeg(x,y))
show(LatexExpr(r'\Xi(x,y) ='), exp(2*ka(x,y)))
show(LatexExpr(r'\phi ='), -lambda5(x,y)/alpha0)
show(LatexExpr(r'\Psi ='), exp(2 * alpha0 * Phi_sc.expr()))
show(LatexExpr(r'k(x,y) ='), kappa(x,y).collect(x))
# Out:
# \lambda_5(x,y) =  lambda_0*x/(x^2 + y^2)
# \nu(x,y) =  e^(-lambda_5(x, y))
# \omega(x,y) =  -(x^2 + 1)*L*lambda_0*y/((x^2 + y^2)*f0)
# \Xi(x,y) = e^(2*k(x, y))
# \phi = -lambda_5(x, y)/alpha0
# \Psi = e^(-2*lambda_5(x, y))
# k(x,y) = 1/4*(8*(x^2 + 1)*x^2*y^2 - (2*x^2 + y^2 + 1)*(x^2 + y^2)^2)*(y^2 - 1)^2*k_0*lambda_0^2/(x^2 + y^2)^4

# %% [markdown]
# ## IV. 1 Metric and potential vector expressions

# %%
h = g.copy(name = r'g_{\mu\nu}')
A_vect = pot_vec.copy()

B(x,y) = L^2 * (x^2 + y^2) * Xi(x,y) / (x^2 + 1)
C(x,y) = L^2 * (x^2 + y^2) * Xi(x,y) / (1 - y^2)
D(x,y) = L^2 * (x^2 + 1)*(1 - y^2) - omega(x,y)
E(x,y) = omega(x,y)

At_expr(x,y) = 1/(2 * k0) * nu(x,y)
Ap_expr(x,y) = -1/(2 * k0) * (omega(x,y) / L) * nu(x,y)

show(subs_func(h).display())
show(LatexExpr(r'A_{\mu\nu} = '), subs_func(A_vect).display())
# Out:
# g_{\mu\nu} = -dt⊗dt - L*lambda_0/((x^2 + y^2)*(x^2 + 1)*y) dt⊗dph + (x^2 + y^2)*L^2*e^(1/2*(8*(x^2 + 1)*x^2*y^2 - (2*x^2 + y^2 + 1)*(x^2 + y^2)^2)*(y^2 - 1)^2*k_0*lambda_0^2/(x^2 + y^2)^4)/(x^2 + 1) dx⊗dx - (x^2 + y^2)*L^2*e^(1/2*(8*(x^2 + 1)*x^2*y^2 - (2*x^2 + y^2 + 1)*(x^2 + y^2)^2)*(y^2 - 1)^2*k_0*lambda_0^2/(x^2 + y^2)^4)/(y^2 - 1) dy⊗dy - L*lambda_0/((x^2 + y^2)*(x^2 + 1)*y) dph⊗dt + (-(x^2 + 1)*(y^2 - 1)*L^2 + L*lambda_0/((x^2 + y^2)*(x^2 + 1)*y)) dph⊗dph
# A_{\mu\nu} =  1/2*e^(-lambda_0*x/(x^2 + y^2))/k_0 dt + 1/2*lambda_0*e^(-lambda_0*x/(x^2 + y^2))/((x^2 + y^2)*(x^2 + 1)*k_0*y) dph

# %% [markdown]
# # IV. Maxwell equations

# %% [markdown]
# ## III.1. Verification of the Maxwell equations $\bigtriangledown_{\mu}(e^{-2\alpha\Phi}F^{\mu\nu})=0$

# %%
eq1 = nab(Fuu / Psi(x,y))

# %%
eq = eq1['^a._a']

# %%
eq.display()
# Out:
# 1/2*(2*(Psi(x, y)*V(x, y)*X(x, y)^2*Z(x, y)^3 + Psi(x, y)*V(x, y)*X(x, y)^2*Y(x, y)*Z(x, y))*d^2(A_phi)/dx^2 + 2*(Psi(x, y)*V(x, y)^2*X(x, y)*Z(x, y)^3 + Psi(x, y)*V(x, y)^2*X(x, y)*Y(x, y)*Z(x, y))*d^2(A_phi)/dy^2 - 2*(Psi(x, y)*V(x, y)*X(x, y)^2*Y(x, y)*Z(x, y)^2 + Psi(x, y)*V(x, y)*X(x, y)^2*Y(x, y)^2)*d^2(A_t)/dx^2 - 2*(Psi(x, y)*V(x, y)^2*X(x, y)*Y(x, y)*Z(x, y)^2 + Psi(x, y)*V(x, y)^2*X(x, y)*Y(x, y)^2)*d^2(A_t)/dy^2 - 2*((V(x, y)*X(x, y)^2*Z(x, y)^3 + V(x, y)*X(x, y)^2*Y(x, y)*Z(x, y))*d(A_phi)/dx - (V(x, y)*X(x, y)^2*Y(x, y)*Z(x, y)^2 + V(x, y)*X(x, y)^2*Y(x, y)^2)*d(A_t)/dx)*d(Psi)/dx - 2*((V(x, y)^2*X(x, y)*Z(x, y)^3 + V(x, y)^2*X(x, y)*Y(x, y)*Z(x, y))*d(A_phi)/dy - (V(x, y)^2*X(x, y)*Y(x, y)*Z(x, y)^2 + V(x, y)^2*X(x, y)*Y(x, y)^2)*d(A_t)/dy)*d(Psi)/dy - ((Psi(x, y)*X(x, y)^2*Z(x, y)^3 + Psi(x, y)*X(x, y)^2*Y(x, y)*Z(x, y))*d(A_phi)/dx - (Psi(x, y)*X(x, y)^2*Y(x, y)*Z(x, y)^2 + Psi(x, y)*X(x, y)^2*Y(x, y)^2)*d(A_t)/dx)*d(V)/dx + ((Psi(x, y)*V(x, y)*X(x, y)*Z(x, y)^3 + Psi(x, y)*V(x, y)*X(x, y)*Y(x, y)*Z(x, y))*d(A_phi)/dy - (Psi(x, y)*V(x, y)*X(x, y)*Y(x, y)*Z(x, y)^2 + Psi(x, y)*V(x, y)*X(x, y)*Y(x, y)^2)*d(A_t)/dy)*d(V)/dy + ((Psi(x, y)*V(x, y)*X(x, y)*Z(x, y)^3 + Psi(x, y)*V(x, y)*X(x, y)*Y(x, y)*Z(x, y))*d(A_phi)/dx - (Psi(x, y)*V(x, y)*X(x, y)*Y(x, y)*Z(x, y)^2 + Psi(x, y)*V(x, y)*X(x, y)*Y(x, y)^2)*d(A_t)/dx)*d(X)/dx - ((Psi(x, y)*V(x, y)^2*Z(x, y)^3 + Psi(x, y)*V(x, y)^2*Y(x, y)*Z(x, y))*d(A_phi)/dy - (Psi(x, y)*V(x, y)^2*Y(x, y)*Z(x, y)^2 + Psi(x, y)*V(x, y)^2*Y(x, y)^2)*d(A_t)/dy)*d(X)/dy - (Psi(x, y)*V(x, y)*X(x, y)^2*Z(x, y)*d(A_phi)/dx + (2*Psi(x, y)*V(x, y)*X(x, y)^2*Z(x, y)^2 + Psi(x, y)*V(x, y)*X(x, y)^2*Y(x, y))*d(A_t)/dx)*d(Y)/dx - (Psi(x, y)*V(x, y)^2*X(x, y)*Z(x, y)*d(A_phi)/dy + (2*Psi(x, y)*V(x, y)^2*X(x, y)*Z(x, y)^2 + Psi(x, y)*V(x, y)^2*X(x, y)*Y(x, y))*d(A_t)/dy)*d(Y)/dy + 2*(Psi(x, y)*V(x, y)*X(x, y)^2*Y(x, y)*Z(x, y)*d(A_t)/dx + Psi(x, y)*V(x, y)*X(x, y)^2*Y(x, y)*d(A_phi)/dx)*d(Z)/dx + 2*(Psi(x, y)*V(x, y)^2*X(x, y)*Y(x, y)*Z(x, y)*d(A_t)/dy + Psi(x, y)*V(x, y)^2*X(x, y)*Y(x, y)*d(A_phi)/dy)*d(Z)/dy)/(Psi(x, y)^2*V(x, y)^2*X(x, y)^2*Z(x, y)^4 + 2*Psi(x, y)^2*V(x, y)^2*X(x, y)^2*Y(x, y)*Z(x, y)^2 + Psi(x, y)^2*V(x, y)^2*X(x, y)^2*Y(x, y)^2) ∂/∂t + 1/2*(2*(Psi(x, y)*V(x, y)*X(x, y)^2*Z(x, y)^2 + Psi(x, y)*V(x, y)*X(x, y)^2*Y(x, y))*d^2(A_phi)/dx^2 + 2*(Psi(x, y)*V(x, y)^2*X(x, y)*Z(x, y)^2 + Psi(x, y)*V(x, y)^2*X(x, y)*Y(x, y))*d^2(A_phi)/dy^2 + 2*(Psi(x, y)*V(x, y)*X(x, y)^2*Z(x, y)^3 + Psi(x, y)*V(x, y)*X(x, y)^2*Y(x, y)*Z(x, y))*d^2(A_t)/dx^2 + 2*(Psi(x, y)*V(x, y)^2*X(x, y)*Z(x, y)^3 + Psi(x, y)*V(x, y)^2*X(x, y)*Y(x, y)*Z(x, y))*d^2(A_t)/dy^2 - 2*((V(x, y)*X(x, y)^2*Z(x, y)^2 + V(x, y)*X(x, y)^2*Y(x, y))*d(A_phi)/dx + (V(x, y)*X(x, y)^2*Z(x, y)^3 + V(x, y)*X(x, y)^2*Y(x, y)*Z(x, y))*d(A_t)/dx)*d(Psi)/dx - 2*((V(x, y)^2*X(x, y)*Z(x, y)^2 + V(x, y)^2*X(x, y)*Y(x, y))*d(A_phi)/dy + (V(x, y)^2*X(x, y)*Z(x, y)^3 + V(x, y)^2*X(x, y)*Y(x, y)*Z(x, y))*d(A_t)/dy)*d(Psi)/dy - ((Psi(x, y)*X(x, y)^2*Z(x, y)^2 + Psi(x, y)*X(x, y)^2*Y(x, y))*d(A_phi)/dx + (Psi(x, y)*X(x, y)^2*Z(x, y)^3 + Psi(x, y)*X(x, y)^2*Y(x, y)*Z(x, y))*d(A_t)/dx)*d(V)/dx + ((Psi(x, y)*V(x, y)*X(x, y)*Z(x, y)^2 + Psi(x, y)*V(x, y)*X(x, y)*Y(x, y))*d(A_phi)/dy + (Psi(x, y)*V(x, y)*X(x, y)*Z(x, y)^3 + Psi(x, y)*V(x, y)*X(x, y)*Y(x, y)*Z(x, y))*d(A_t)/dy)*d(V)/dy + ((Psi(x, y)*V(x, y)*X(x, y)*Z(x, y)^2 + Psi(x, y)*V(x, y)*X(x, y)*Y(x, y))*d(A_phi)/dx + (Psi(x, y)*V(x, y)*X(x, y)*Z(x, y)^3 + Psi(x, y)*V(x, y)*X(x, y)*Y(x, y)*Z(x, y))*d(A_t)/dx)*d(X)/dx - ((Psi(x, y)*V(x, y)^2*Z(x, y)^2 + Psi(x, y)*V(x, y)^2*Y(x, y))*d(A_phi)/dy + (Psi(x, y)*V(x, y)^2*Z(x, y)^3 + Psi(x, y)*V(x, y)^2*Y(x, y)*Z(x, y))*d(A_t)/dy)*d(X)/dy - (Psi(x, y)*V(x, y)*X(x, y)^2*Z(x, y)*d(A_t)/dx + Psi(x, y)*V(x, y)*X(x, y)^2*d(A_phi)/dx)*d(Y)/dx - (Psi(x, y)*V(x, y)^2*X(x, y)*Z(x, y)*d(A_t)/dy + Psi(x, y)*V(x, y)^2*X(x, y)*d(A_phi)/dy)*d(Y)/dy - 2*(Psi(x, y)*V(x, y)*X(x, y)^2*Z(x, y)*d(A_phi)/dx - Psi(x, y)*V(x, y)*X(x, y)^2*Y(x, y)*d(A_t)/dx)*d(Z)/dx - 2*(Psi(x ...

# %%
subs_func(eq)[0].factor()
# Out:
# 1/4*(2*L^2*lambda_0*x^26*y^10*e^(3*k_0*lambda_0^2*x^4*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^10/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 7*k_0*lambda_0^2*x^4*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^8/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 5*k_0*lambda_0^2*x^4*y^2/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*x^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8)) + 2*L^2*lambda_0*x^24*y^12*e^(3*k_0*lambda_0^2*x^4*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^10/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 7*k_0*lambda_0^2*x^4*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^8/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 5*k_0*lambda_0^2*x^4*y^2/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*x^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8)) - 12*L^2*lambda_0*x^22*y^14*e^(3*k_0*lambda_0^2*x^4*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^10/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 7*k_0*lambda_0^2*x^4*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^8/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 5*k_0*lambda_0^2*x^4*y^2/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*x^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8)) - 28*L^2*lambda_0*x^20*y^16*e^(3*k_0*lambda_0^2*x^4*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^10/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 7*k_0*lambda_0^2*x^4*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^8/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 5*k_0*lambda_0^2*x^4*y^2/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*x^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8)) - 22*L^2*lambda_0*x^18*y^18*e^(3*k_0*lambda_0^2*x^4*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^10/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 7*k_0*lambda_0^2*x^4*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^8/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 5*k_0*lambda_0^2*x^4*y^2/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*x^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8)) - 6*L^2*lambda_0*x^16*y^20*e^(3*k_0*lambda_0^2*x^4*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^10/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 7*k_0*lambda_0^2*x^4*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^8/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 5*k_0*lambda_0^2*x^4*y^2/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*x^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8)) - 4*L^2*lambda_0*x^26*y^8*e^(3*k_0*lambda_0^2*x^4*y^6/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^10/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 7*k_0*lambda_0^2*x^4*y^4/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k_0*lambda_0^2*y^8/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + 5*k_0*lambda_0^2*x^4*y^2/(x^8 + 4*x^6*y^2 + 6*x^4*y^4 + 4*x^2*y^6 + y^8) + k ...

# %%
eq == 0
# Out:
# False

# %%
g[0,0] = -fu(x,y)
g[0,3] = g[3,0] = fu(x,y) * omega(x,y)
g[3,3] = L^2*fu(x,y)^(-1) * (x^2 + 1)*(1 - y^2) - fu(x,y)* omega(x,y)
g[1,1] = L^2*fu(x,y)^(-1) * (x^2 + y^2) * Xi(x,y) / (x^2 + 1)
g[2,2] = L^2*fu(x,y)^(-1) * (x^2 + y^2) * Xi(x,y) / (1 - y^2)

pot_vec[0] = sqrt(f0)/(2 * k0) * nu(x,y)
pot_vec[1]=0
pot_vec[2]=0
pot_vec[3]= -sqrt(f0)/(2 * k0) * (omega(x,y) / L) * nu(x,y)
